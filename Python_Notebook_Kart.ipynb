# %% [markdown]
# <a href="https://colab.research.google.com/github/KMadavar/BMIplot/blob/main/Python_Notebook_Kart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
import time
print(time.ctime())
# Out:
# Sat Nov 22 15:54:16 2025
